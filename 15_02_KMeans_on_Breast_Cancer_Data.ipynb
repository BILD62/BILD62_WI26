# %% [markdown]
# # Applying K-means clustering on sample biological data
#
# ### By the end of this notebook, you will be able to:
# - Load a toy biological dataset from sklearn
# - Apply K-means clustering on the dataset
# - Evaluate the quality and utility of clustering

# %% [markdown]
# ### Load packages

# %%
# The usual suspects - np, pd and plt
...

# Packages from sklearn
from sklearn.cluster import KMeans
from sklearn.datasets import load_breast_cancer
from sklearn.decomposition import PCA

# Seaborn is another useful package for plotting data
import seaborn as sns

# %% [markdown]
# ### Load and pre-process Wisconsin Breast Cancer Dataset
# This is one of the many toy datasets available in the sklearn package.
#
# Learn more about the dataset at: https://scikit-learn.org/stable/datasets/toy_dataset.html#breast-cancer-dataset
#
# How to load the data: https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_breast_cancer.html

# %%
# Load the data
data = ...

# For ease, store the data and labels in different variables
brca_data = data.data
brca_target = data.target

# Some pre-processing of data
# Subsample dataset and apply Principal Components Analysis (PCA) [details unimportant for now]
brca_to_retain = [0, 1, 10, 11]
brca_data_filtered = brca_data[:,brca_to_retain]
brca_pca = PCA(n_components=2)
brca_pca_props = brca_pca.fit(brca_data_filtered)
# print(f'{brca_pca_props.explained_variance_ratio_.sum()*100:.2f}% Variance Explained')
brca_pca_data = brca_pca.fit_transform(brca_data_filtered)
# Out:
# 99.10% Variance Explained

# %% [markdown]
# ### Apply K-means clustering on processed (PCA) data

# %%
# Apply K-Means Clustering on BRCA PCA data (brca_pca_data)
brca_kmeans = ...

# Prepare hue labels as strings using data.target_names for consistency in legend
true_labels_str = np.array([data.target_names[label] for label in brca_target])
kmeans_labels_str = np.array([data.target_names[label] for label in brca_kmeans.labels_])

# %% [markdown]
# ### Assessing the result of clustering 1 - Plot the resulting data

# %%
# Plotting
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Define colour palette
color_palette = {data.target_names[0]: 'red', data.target_names[1]: 'blue'}

# Plot 1: Actual Target Labels
sns.scatterplot(x=..., y=..., hue=true_labels_str, palette=color_palette, ax=axes[0])

axes[0].set_title('PCA of Breast Cancer Data (True Labels)')
axes[0].set_xlabel('Principal Component 1')
axes[0].set_ylabel('Principal Component 2')
axes[0].legend(title='Diagnosis')

# Plot 2: K-Means Cluster Labels (re-aligned)
sns.scatterplot(x=..., y=..., hue=kmeans_labels_str, palette=color_palette, ax=axes[1])
axes[1].set_title('PCA of Breast Cancer Data (K-Means Clusters Aligned)')
axes[1].set_xlabel('Principal Component 1')
axes[1].set_ylabel('Principal Component 2')
axes[1].legend(title='Cluster Diagnosis')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Assessing the result of clustering 2 - Contingency table

# %%
# How well did K-means do? Contingency table.
contingency_table = pd.crosstab(true_labels_str, kmeans_labels_str)

# What's the problem here? How do you think you can fix this? [For your exploration]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_659/2372085421.py in <cell line: 0>()
#       1 # How well did K-means do? Contingency table.
# ----> 2 contingency_table = pd.crosstab(true_labels_str, kmeans_labels_str)
#       3
#       4 # What's the problem here? How do you think you can fix this? [For your exploration]
#
# NameError: name 'pd' is not defined
